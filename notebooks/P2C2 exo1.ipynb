# %% [markdown]
# <a href="https://colab.research.google.com/github/Victoria-tec/python_exercises_openclassroom/blob/main/notebooks/P2C2%20exo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![openclassrooms](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/6204541/1+HnqdJ-5ofxiPP9HIxdNdpw.jpeg)
#
# # Initiez-vous à Python pour l'analyse de données
#
# ## Manipulez les types de variables
#
# Reprenons la problématique du taux d'intérêt du chapitre précédent :

# %%
compteEpargne = 10000
taux = 0.75

interets = compteEpargne * (taux/100)

print(interets)
# Out:
# 75.0

# %% [markdown]
# Si vous observez bien, la variable `interets` est actuellement de type `float`. Ecrivez ci dessous une ligne permettant de la transformer en entier :

# %%
interets = int(interets)
print(interets)
# Out:
# 75
