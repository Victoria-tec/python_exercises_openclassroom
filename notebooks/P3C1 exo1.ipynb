# %% [markdown]
# <a href="https://colab.research.google.com/github/Victoria-tec/python_exercises_openclassroom/blob/main/notebooks/P3C1%20exo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![openclassrooms](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/6204541/1+HnqdJ-5ofxiPP9HIxdNdpw.jpeg)
#
# # Initiez-vous à Python pour l'analyse de données
#
# ## Créez des tableaux pour stocker vos variables
#
# <br><br>
#
# **Une liste pour les gouverner tous**
#
# Déclarez une liste `couleurs` contenant 5 éléments : `rouge`, `jaune`, `orange`, `vert` et `bleu`.

# %%
couleurs = ['rouge','jaune', 'orange', 'vert', 'bleu']

# %% [markdown]
# Remplacez la couleur `vert` par `émeraude` :

# %%
couleurs[3]='émeraude'

# %% [markdown]
# Affichez le contenu de la liste :

# %%
print(couleurs)
# Out:
# ['rouge', 'jaune', 'orange', 'émeraude', 'bleu']
